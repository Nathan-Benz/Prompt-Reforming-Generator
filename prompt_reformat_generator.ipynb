# %% [markdown]
# <a href="https://colab.research.google.com/github/Nathan-Benz/Prompt-Reforming-Generator/blob/main/prompt_reformat_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Set Up

# %% [markdown]
# Installing libraries

# %%
# !pip install autotrain-advanced
# !pip install huggingface_hub

# %%
# !autotrain setup --update-torch
# Out:
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cpu.so: undefined symbol: cadam32bit_grad_fp32
# 2023-08-08 03:19:33.911360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# > INFO    Installing latest transformers@main
# > INFO    Successfully installed latest transformers
# > INFO    Installing latest peft@main
# > INFO    Successfully installed latest peft
# > INFO    Installing latest diffusers@main
# > INFO    Successfully installed latest diffusers
# > INFO    Installing latest trl@main
# > INFO    Successfully installed latest trl
# > INFO    Installing latest PyTorch
# ...

# %% [markdown]
# HuggingFace Login

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# # Training

# %% [markdown]
# Setting up hyperparameters

# %%
# !autotrain llm --train --project_name 'llama2-prompt-optimizer' --model TinyPixel/Llama-2-7B-bf16-sharded --data_path NateBenz/formatted_prompts --use_peft --use_int4 --learning_rate 2e-4 --train_batch_size 2 --num_train_epochs 3 --trainer sft --model_max_length 2048 --block_size 2048 > training.log &
# Out:
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 2023-08-08 03:24:24.304935: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# > INFO    Running LLM
# > INFO    Train: True
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:2069: FutureWarning: 'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'token=None' instead.
#   warnings.warn(
# Using pad_token, but it is not set yet.
# Traceback (most recent call last):
#   File "/usr/local/bin/autotrain", line 8, in <module>
#     sys.exit(main())
# ...

# %%
# !autotrain llm --train --project_name 'llama2-prompt-optimizer' \
--model TinyPixel/Llama-2-7B-bf16-sharded \
--data_path vicgalle/alpaca-gpt4 \
--text_column text \
--use_peft \
--use_int4 \
--learning_rate 2e-4 \
--train_batch_size 2 \
--num_train_epochs 3 \
--trainer sft \
--model_max_length 2048 \
--block_size 2048 > training.log &
# Out:
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 2023-08-08 03:24:40.730290: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# > INFO    Running LLM
# > INFO    Train: True
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:2069: FutureWarning: 'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'token=None' instead.
#   warnings.warn(
# Using pad_token, but it is not set yet.
# Traceback (most recent call last):
#   File "/usr/local/bin/autotrain", line 8, in <module>
#     sys.exit(main())
# ...

# %%
#--push_to_hub \
#--repo_id NateBenz/llama2-prompt-reformatting-generator/llama2-prompt-optimizer \
