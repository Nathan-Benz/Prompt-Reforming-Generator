# %% [markdown]
# <a href="https://colab.research.google.com/github/Nathan-Benz/Prompt-Reforming-Generator/blob/main/prompt_reformat_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Set Up

# %% [markdown]
# Installing libraries

# %%
# !pip install autotrain-advanced
# !pip install huggingface_hub
# Out:
# ...
#   Using cached peft-0.4.0-py3-none-any.whl (72 kB)
# ...

# %%
# !autotrain setup --update-torch
# Out:
# 2023-08-07 17:39:00.353018: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# > INFO    Installing latest transformers@main
# > INFO    Successfully installed latest transformers
# > INFO    Installing latest peft@main
# > INFO    Successfully installed latest peft
# > INFO    Installing latest diffusers@main
# > INFO    Successfully installed latest diffusers
# > INFO    Installing latest trl@main
# > INFO    Successfully installed latest trl
# > INFO    Installing latest PyTorch
# > INFO    Successfully installed latest PyTorch

# %% [markdown]
# HuggingFace Login

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# # Training

# %% [markdown]
# Setting up hyperparameters

# %%
# !autotrain llm --train --project_name 'llama2-openassistant' --model TinyPixel/Llama-2-7B-bf16-sharded --data_path AlexanderDoria/novel17_test --use_peft --use_int4 --learning_rate 2e-4 --train_batch_size 2 --num_train_epochs 3 --trainer sft --model_max_length 2048 --block_size 2048 > training.log &
#--push_to_hub
#--repo_id your_repo_id
# Out:
# 2023-08-07 17:42:15.551030: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# > INFO    Running LLM
# > INFO    Train: True
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:2069: FutureWarning: 'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'token=None' instead.
#   warnings.warn(
# ...
# Extracting data files: 100% 2/2 [00:00<00:00, 1118.48it/s]
# Generating train split: 1 examples [00:00, 25.30 examples/s]
# Generating test split: 1 examples [00:00, 737.40 examples/s]
# ...
# Using pad_token, but it is not set yet.
# ...
# Loading checkpoint shards: 100% 14/14 [01:26<00:00,  6.16s/it]
# ...
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:119: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# ...
